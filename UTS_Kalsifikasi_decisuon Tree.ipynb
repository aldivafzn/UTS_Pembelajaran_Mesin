# %% [markdown]
# ## Import Library yang ingin Dipakai

# %%
import pandas as pd

#aldivafadliefauzan_202131017

# %% [markdown]
# ## Menampilkan Dataset

# %%
hasil = pd.read_csv ('K04_bank_customers.csv', delimiter=';', quotechar='"')
hasil

#aldivafadliefauzan_202131017
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
hasil.info ()

#aldivafadliefauzan_202131017
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
jumlah_kosong = hasil.isna().sum()
jumlah_kosong

#aldivafadliefauzan_202131017
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
hasil.describe ()

#aldivafadliefauzan_202131017
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
print (hasil.columns)

#aldivafadliefauzan_202131017
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# ## Preprosesing Data

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'hasil' is your DataFrame
for col in ['age', 'job', 'marital', 'education', 'default', 'balance',
            'housing', 'loan', 'contact', 'day', 'month', 'duration',
            'campaign', 'pdays', 'previous', 'poutcome','y']:
    # Check if the column exists in the DataFrame
    if col in hasil.columns:
        # Check the data type before applying LabelEncoder
        if hasil[col].dtype == 'object':
            label_encoder = LabelEncoder()
            hasil[col] = label_encoder.fit_transform(hasil[col])
        else:
            # Handle other data types (if needed)
            print(f"Skipping encoding for non-object column: {col}")
    else:
        print(f"Column '{col}' not found in the DataFrame.")

#aldivafadliefauzan_202131017
# Out:
# Skipping encoding for non-object column: age
# Skipping encoding for non-object column: balance
# Skipping encoding for non-object column: day
# Skipping encoding for non-object column: duration
# Skipping encoding for non-object column: campaign
# Skipping encoding for non-object column: pdays
# Skipping encoding for non-object column: previous

# %%
hasil

#aldivafadliefauzan_202131017
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %% [markdown]
# ## Memisahkan Kolom Target

# %%
x = hasil.drop ('y', axis=1)
y = hasil ['y']

#aldivafadliefauzan_202131017

# %%
x

#aldivafadliefauzan_202131017
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %%
y

#aldivafadliefauzan_202131017
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, Length: 45211, dtype: int32

# %% [markdown]
# ## Splitting Data Testting dan Traning?

# %%
from sklearn.model_selection import train_test_split

#aldivafadliefauzan_202131017

# %% [markdown]
# ## 80 : 20

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2)

#aldivafadliefauzan_202131017

# %% [markdown]
# #### Desision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
modelDT = DecisionTreeClassifier (max_depth = 5)
modelDT.fit (x_train, y_train)

#aldivafadliefauzan_202131017
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
# Testing model untuk melakukan Prediksi
hasil_prediksi = modelDT.predict (x_test)

#aldivafadliefauzan_202131017

# %%
from sklearn.metrics import accuracy_score
hasil_prediksi_dt = modelDT.predict (x_test)
print ('Akurasi Model : ', accuracy_score (y_test, hasil_prediksi_dt)*100)

#aldivafadliefauzan_202131017
# Out:
# Akurasi Model :  89.4061705186332

# %% [markdown]
# ## Test Data

# %%
data_baru = ([[71,5,0,0,0,1729,0,0,0,17,9,456,2,-1,0,3]])
hasil_prediksi = modelDT.predict (data_baru)
if hasil_prediksi == 1:
    print("Pelanggan Tertarik")
elif hasil_prediksi == 0:
    print("Pelanggan Tidak Tetarik")
else:
    print("Hasil prediksi tidak valid")
    
    #aldivafadliefauzan_202131017
# Out:
# Pelanggan Tertarik
# c:\Users\User\Documents\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Visualisasi Data

# %%
# Visualisasi model Decision Tree
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

#aldivafadliefauzan_202131017

# %%
plt.subplots (figsize=(40,20))
plot_tree(modelDT, fontsize = 20)
plt.show()

#aldivafadliefauzan_202131017
